# %%
# !git clone https://github.com/atharvajoshi10/quantized-lag-llama
# Out:
# Cloning into 'quantized-lag-llama'...

# %%
# !move quantized-lag-llama\lag_llama .\lag_llama
# Out:
#         1 dir(s) moved.

# %%
# !move quantized-lag-llama\data .\data
# Out:
#         1 dir(s) moved.

# %%
# !move quantized-lag-llama\gluon_utils .\gluon_utils
# Out:
#         1 dir(s) moved.

# %%
# %%capture
# %pip install -r requirements.txt

# %%
from itertools import islice
from matplotlib import pyplot as plt
import matplotlib.dates as mdates
import torch
from gluonts.evaluation import make_evaluation_predictions, Evaluator
from gluonts.dataset.repository.datasets import get_dataset
from gluonts.dataset.pandas import PandasDataset
import pandas as pd
# Out:
# c:\Python\Lib\site-packages\gluonts\json.py:101: UserWarning: Using `json`-module for json-handling. Consider installing one of `orjson`, `ujson` to speed up serialization and deserialization.
#   warnings.warn(

# %%
import pandas as pd
from gluonts.dataset.pandas import PandasDataset
df = pd.read_csv("electricity.csv", index_col=0, parse_dates=True)

# %%
df["item_id"] = "MT_001"
df.rename(columns={"MT_001": "target"}, inplace=True)

# %%
df = df[["target", "item_id"]]

# %%
for col in df.columns:
    # Check if column is not of string type
    if df[col].dtype != 'object' and pd.api.types.is_string_dtype(df[col]) == False:
        df[col] = df[col].astype('float32')
# Out:
# C:\Users\athu2\AppData\Local\Temp\ipykernel_42940\29596338.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype('float32')

# %%
df.head()
# Out:
#                  target item_id
# 2012-01-02  1025.380737  MT_001
# 2012-01-03  1040.609131  MT_001
# 2012-01-04  1093.908569  MT_001
# 2012-01-05  1351.522827  MT_001
# 2012-01-06  1331.218262  MT_001

# %%
dataset = PandasDataset.from_long_dataframe(df, target="target", item_id="item_id")

# %%
backtest_dataset = dataset
prediction_length = 24  # Define your prediction length. We use 24 here since the data is of hourly frequency
num_samples = 100 # number of samples sampled from the probability distribution for each timestep
device = torch.device("cpu") # You can switch this to CPU or other GPUs if you'd like, depending on your environment

# %%
from lag_llama.gluon.quantized_estimator import QuantizedLagLlamaEstimator

# %%
def get_quantized_models(prediction_length, device):
    ckpt = torch.load("lag-llama.ckpt", map_location=device) # Uses GPU since in this Colab we use a GPU.
    estimator_args = ckpt["hyper_parameters"]["model_kwargs"]

    estimator = QuantizedLagLlamaEstimator(
        ckpt_path="lag-llama.ckpt",
        prediction_length=prediction_length,
        context_length=32, # Should not be changed; this is what the released Lag-Llama model was trained with

        # estimator args
        input_size=estimator_args["input_size"],
        n_layer=estimator_args["n_layer"],
        n_embd_per_head=estimator_args["n_embd_per_head"],
        n_head=estimator_args["n_head"],
        scaling=estimator_args["scaling"],
        time_feat=estimator_args["time_feat"],

        batch_size=1,
        num_parallel_samples=100,
        device=device,
    )

    lightning_module = estimator.create_lightning_module()

    return estimator, lightning_module

# %%
q_estimator, q_lightning_module = get_quantized_models(prediction_length, device)
q_lightning_module.model.qconfig = torch.ao.quantization.default_qconfig
q_lightning_module.model = torch.ao.quantization.prepare(q_lightning_module.model)
q_lightning_module.model
# Out:
# QuantizedLagLlamaModel(
#   (param_proj): QuantizedPtArgProj(
#     (proj): ModuleList(
#       (0-2): 3 x Linear(
#         in_features=144, out_features=1, bias=True
#         (activation_post_process): MinMaxObserver(min_val=inf, max_val=-inf)
#       )
#     )
#     (domain_map): LambdaLayer()
#     (quant): QuantStub(
#       (activation_post_process): MinMaxObserver(min_val=inf, max_val=-inf)
#     )
#     (dequant): DeQuantStub()
#   )
#   (quant1): QuantStub(
#     (activation_post_process): MinMaxObserver(min_val=inf, max_val=-inf)
#   )
#   (dequant1): DeQuantStub()
#   (quant2): QuantStub(
#     (activation_post_process): MinMaxObserver(min_val=inf, max_val=-inf)
#   )
#   (dequant2): DeQuantStub()
#   (transformer): ModuleDict(
#     (wte): Linear(
#       in_features=92, out_features=144, bias=True
#       (activation_post_process): MinMaxObserver(min_val=inf, max_val=-inf)
#     )
#     (h): ModuleList(
#       (0-7): 8 x QuantizedBlock(
#         (rms_1): RMSNorm()
#         (attn): QuantizedCausalSelfAttention(
#           (q_proj): Linear(
#             in_features=144, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=inf, max_val=-inf)
#           )
#           (kv_proj): Linear(
#             in_features=144, out_features=288, bias=False
#             (activation_post_process): MinMaxObserver(min_val=inf, max_val=-inf)
#           )
#           (c_proj): Linear(
#             in_features=144, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=inf, max_val=-inf)
#           )
#           (quant1): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=inf, max_val=-inf)
#           )
#           (quant2): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=inf, max_val=-inf)
#           )
#           (dequant1): DeQuantStub()
#           (dequant2): DeQuantStub()
#           (dequant3): DeQuantStub()
#           (dequant4): DeQuantStub()
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (rms_2): RMSNorm()
#         (mlp): QuantizedMLP(
#           (quant1): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=inf, max_val=-inf)
#           )
#           (quant2): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=inf, max_val=-inf)
#           )
#           (dequant1): DeQuantStub()
#           (dequant2): DeQuantStub()
#           (dequant3): DeQuantStub()
#           (c_fc1): Linear(
#             in_features=144, out_features=512, bias=False
#             (activation_post_process): MinMaxObserver(min_val=inf, max_val=-inf)
#           )
#           (c_fc2): Linear(
#             in_features=144, out_features=512, bias=False
#             (activation_post_process): MinMaxObserver(min_val=inf, max_val=-inf)
#           )
#           (c_proj): Linear(
#             in_features=512, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=inf, max_val=-inf)
#           )
#         )
#       )
#     )
#     (ln_f): RMSNorm()
#   )
# )

# %%
def observe_value_ranges(quantized_estimator, quantized_lightning_module, dataset, num_samples=100):
    transformation = quantized_estimator.create_transformation()
    predictor = quantized_estimator.create_predictor(transformation, quantized_lightning_module)
    forecast_it, ts_it = make_evaluation_predictions(
        dataset=dataset,
        predictor=predictor,
        num_samples=num_samples
    )
    forecasts = list(forecast_it)
    tss = list(ts_it)

    return forecasts, tss, quantized_lightning_module, quantized_estimator

# %%
forecasts, tss, q_lightning_module, q_estimator = observe_value_ranges(q_estimator, q_lightning_module, backtest_dataset, num_samples)

# %%
q_lightning_module.model
# Out:
# QuantizedLagLlamaModel(
#   (param_proj): QuantizedPtArgProj(
#     (proj): ModuleList(
#       (0): Linear(
#         in_features=144, out_features=1, bias=True
#         (activation_post_process): MinMaxObserver(min_val=-4.10621452331543, max_val=6.365020275115967)
#       )
#       (1): Linear(
#         in_features=144, out_features=1, bias=True
#         (activation_post_process): MinMaxObserver(min_val=-3.486754894256592, max_val=4.824054718017578)
#       )
#       (2): Linear(
#         in_features=144, out_features=1, bias=True
#         (activation_post_process): MinMaxObserver(min_val=-3.2084405422210693, max_val=2.362924337387085)
#       )
#     )
#     (domain_map): LambdaLayer()
#     (quant): QuantStub(
#       (activation_post_process): MinMaxObserver(min_val=-4.430831432342529, max_val=6.431379318237305)
#     )
#     (dequant): DeQuantStub()
#   )
#   (quant1): QuantStub(
#     (activation_post_process): MinMaxObserver(min_val=-4.651116371154785, max_val=6.46429967880249)
#   )
#   (dequant1): DeQuantStub()
#   (quant2): QuantStub(
#     (activation_post_process): MinMaxObserver(min_val=inf, max_val=-inf)
#   )
#   (dequant2): DeQuantStub()
#   (transformer): ModuleDict(
#     (wte): Linear(
#       in_features=92, out_features=144, bias=True
#       (activation_post_process): MinMaxObserver(min_val=-3.485424757003784, max_val=2.762042999267578)
#     )
#     (h): ModuleList(
#       (0): QuantizedBlock(
#         (rms_1): RMSNorm()
#         (attn): QuantizedCausalSelfAttention(
#           (q_proj): Linear(
#             in_features=144, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-4.318215370178223, max_val=4.783243179321289)
#           )
#           (kv_proj): Linear(
#             in_features=144, out_features=288, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-4.534634590148926, max_val=3.926565170288086)
#           )
#           (c_proj): Linear(
#             in_features=144, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-1.3552178144454956, max_val=1.570131540298462)
#           )
#           (quant1): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-3.691701650619507, max_val=3.3793160915374756)
#           )
#           (quant2): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-1.966676950454712, max_val=2.473942995071411)
#           )
#           (dequant1): DeQuantStub()
#           (dequant2): DeQuantStub()
#           (dequant3): DeQuantStub()
#           (dequant4): DeQuantStub()
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (rms_2): RMSNorm()
#         (mlp): QuantizedMLP(
#           (quant1): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-4.2185821533203125, max_val=3.8068628311157227)
#           )
#           (quant2): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-10.446633338928223, max_val=4.013742923736572)
#           )
#           (dequant1): DeQuantStub()
#           (dequant2): DeQuantStub()
#           (dequant3): DeQuantStub()
#           (c_fc1): Linear(
#             in_features=144, out_features=512, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-3.9019973278045654, max_val=2.8981683254241943)
#           )
#           (c_fc2): Linear(
#             in_features=144, out_features=512, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-4.612717151641846, max_val=3.8757383823394775)
#           )
#           (c_proj): Linear(
#             in_features=512, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-5.626187324523926, max_val=4.125871658325195)
#           )
#         )
#       )
#       (1): QuantizedBlock(
#         (rms_1): RMSNorm()
#         (attn): QuantizedCausalSelfAttention(
#           (q_proj): Linear(
#             in_features=144, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-4.8769989013671875, max_val=4.853358745574951)
#           )
#           (kv_proj): Linear(
#             in_features=144, out_features=288, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-3.581345319747925, max_val=3.3054916858673096)
#           )
#           (c_proj): Linear(
#             in_features=144, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-1.060219645500183, max_val=1.011523723602295)
#           )
#           (quant1): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-3.8925833702087402, max_val=3.584568977355957)
#           )
#           (quant2): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-1.509697437286377, max_val=1.8206636905670166)
#           )
#           (dequant1): DeQuantStub()
#           (dequant2): DeQuantStub()
#           (dequant3): DeQuantStub()
#           (dequant4): DeQuantStub()
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (rms_2): RMSNorm()
#         (mlp): QuantizedMLP(
#           (quant1): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-4.0303449630737305, max_val=3.8320765495300293)
#           )
#           (quant2): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-5.544351100921631, max_val=4.490172863006592)
#           )
#           (dequant1): DeQuantStub()
#           (dequant2): DeQuantStub()
#           (dequant3): DeQuantStub()
#           (c_fc1): Linear(
#             in_features=144, out_features=512, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-3.36641263961792, max_val=3.0006861686706543)
#           )
#           (c_fc2): Linear(
#             in_features=144, out_features=512, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-3.3280344009399414, max_val=3.117968797683716)
#           )
#           (c_proj): Linear(
#             in_features=512, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-2.273550271987915, max_val=3.721734046936035)
#           )
#         )
#       )
#       (2): QuantizedBlock(
#         (rms_1): RMSNorm()
#         (attn): QuantizedCausalSelfAttention(
#           (q_proj): Linear(
#             in_features=144, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-4.613288402557373, max_val=4.599628925323486)
#           )
#           (kv_proj): Linear(
#             in_features=144, out_features=288, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-4.673478603363037, max_val=5.454613208770752)
#           )
#           (c_proj): Linear(
#             in_features=144, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-1.4179857969284058, max_val=1.2770806550979614)
#           )
#           (quant1): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-3.8399033546447754, max_val=4.012637138366699)
#           )
#           (quant2): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-2.1190974712371826, max_val=2.363942861557007)
#           )
#           (dequant1): DeQuantStub()
#           (dequant2): DeQuantStub()
#           (dequant3): DeQuantStub()
#           (dequant4): DeQuantStub()
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (rms_2): RMSNorm()
#         (mlp): QuantizedMLP(
#           (quant1): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-3.861776113510132, max_val=4.191701412200928)
#           )
#           (quant2): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-6.86452054977417, max_val=5.261155128479004)
#           )
#           (dequant1): DeQuantStub()
#           (dequant2): DeQuantStub()
#           (dequant3): DeQuantStub()
#           (c_fc1): Linear(
#             in_features=144, out_features=512, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-3.3429977893829346, max_val=3.586122989654541)
#           )
#           (c_fc2): Linear(
#             in_features=144, out_features=512, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-3.3905117511749268, max_val=2.9061594009399414)
#           )
#           (c_proj): Linear(
#             in_features=512, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-3.0398924350738525, max_val=4.484626770019531)
#           )
#         )
#       )
#       (3): QuantizedBlock(
#         (rms_1): RMSNorm()
#         (attn): QuantizedCausalSelfAttention(
#           (q_proj): Linear(
#             in_features=144, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-4.726906776428223, max_val=5.75767183303833)
#           )
#           (kv_proj): Linear(
#             in_features=144, out_features=288, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-3.69508957862854, max_val=5.007242202758789)
#           )
#           (c_proj): Linear(
#             in_features=144, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-1.9407143592834473, max_val=1.6410140991210938)
#           )
#           (quant1): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-4.075464248657227, max_val=4.355906009674072)
#           )
#           (quant2): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-3.185051202774048, max_val=3.4031801223754883)
#           )
#           (dequant1): DeQuantStub()
#           (dequant2): DeQuantStub()
#           (dequant3): DeQuantStub()
#           (dequant4): DeQuantStub()
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (rms_2): RMSNorm()
#         (mlp): QuantizedMLP(
#           (quant1): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-4.074709892272949, max_val=4.425837993621826)
#           )
#           (quant2): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-6.497849941253662, max_val=8.437545776367188)
#           )
#           (dequant1): DeQuantStub()
#           (dequant2): DeQuantStub()
#           (dequant3): DeQuantStub()
#           (c_fc1): Linear(
#             in_features=144, out_features=512, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-4.6735124588012695, max_val=4.266761302947998)
#           )
#           (c_fc2): Linear(
#             in_features=144, out_features=512, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-3.423724889755249, max_val=4.5066447257995605)
#           )
#           (c_proj): Linear(
#             in_features=512, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-4.421894550323486, max_val=4.943410873413086)
#           )
#         )
#       )
#       (4): QuantizedBlock(
#         (rms_1): RMSNorm()
#         (attn): QuantizedCausalSelfAttention(
#           (q_proj): Linear(
#             in_features=144, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-9.217447280883789, max_val=5.643632888793945)
#           )
#           (kv_proj): Linear(
#             in_features=144, out_features=288, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-5.644988059997559, max_val=7.241669178009033)
#           )
#           (c_proj): Linear(
#             in_features=144, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-3.549011707305908, max_val=3.5119049549102783)
#           )
#           (quant1): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-4.24415397644043, max_val=4.204554080963135)
#           )
#           (quant2): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-5.260818004608154, max_val=4.165709972381592)
#           )
#           (dequant1): DeQuantStub()
#           (dequant2): DeQuantStub()
#           (dequant3): DeQuantStub()
#           (dequant4): DeQuantStub()
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (rms_2): RMSNorm()
#         (mlp): QuantizedMLP(
#           (quant1): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-4.537571907043457, max_val=4.52787446975708)
#           )
#           (quant2): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-10.620248794555664, max_val=8.788126945495605)
#           )
#           (dequant1): DeQuantStub()
#           (dequant2): DeQuantStub()
#           (dequant3): DeQuantStub()
#           (c_fc1): Linear(
#             in_features=144, out_features=512, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-4.246749401092529, max_val=5.079205513000488)
#           )
#           (c_fc2): Linear(
#             in_features=144, out_features=512, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-3.236121654510498, max_val=3.9185571670532227)
#           )
#           (c_proj): Linear(
#             in_features=512, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-3.977281093597412, max_val=4.100444793701172)
#           )
#         )
#       )
#       (5): QuantizedBlock(
#         (rms_1): RMSNorm()
#         (attn): QuantizedCausalSelfAttention(
#           (q_proj): Linear(
#             in_features=144, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-5.146042823791504, max_val=4.653530597686768)
#           )
#           (kv_proj): Linear(
#             in_features=144, out_features=288, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-4.781286239624023, max_val=6.885757923126221)
#           )
#           (c_proj): Linear(
#             in_features=144, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-3.1335582733154297, max_val=3.3691887855529785)
#           )
#           (quant1): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-4.99780797958374, max_val=4.425878047943115)
#           )
#           (quant2): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-4.064725399017334, max_val=4.443850994110107)
#           )
#           (dequant1): DeQuantStub()
#           (dequant2): DeQuantStub()
#           (dequant3): DeQuantStub()
#           (dequant4): DeQuantStub()
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (rms_2): RMSNorm()
#         (mlp): QuantizedMLP(
#           (quant1): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-4.371535301208496, max_val=4.478814125061035)
#           )
#           (quant2): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-8.139730453491211, max_val=8.527241706848145)
#           )
#           (dequant1): DeQuantStub()
#           (dequant2): DeQuantStub()
#           (dequant3): DeQuantStub()
#           (c_fc1): Linear(
#             in_features=144, out_features=512, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-6.048272609710693, max_val=4.843629360198975)
#           )
#           (c_fc2): Linear(
#             in_features=144, out_features=512, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-3.4027302265167236, max_val=3.322089910507202)
#           )
#           (c_proj): Linear(
#             in_features=512, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-4.3238935470581055, max_val=5.743154048919678)
#           )
#         )
#       )
#       (6): QuantizedBlock(
#         (rms_1): RMSNorm()
#         (attn): QuantizedCausalSelfAttention(
#           (q_proj): Linear(
#             in_features=144, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-7.692804336547852, max_val=6.054943084716797)
#           )
#           (kv_proj): Linear(
#             in_features=144, out_features=288, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-5.929708957672119, max_val=5.334770679473877)
#           )
#           (c_proj): Linear(
#             in_features=144, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-2.5621769428253174, max_val=3.352558135986328)
#           )
#           (quant1): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-4.1941399574279785, max_val=5.014437198638916)
#           )
#           (quant2): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-3.242565631866455, max_val=3.0530178546905518)
#           )
#           (dequant1): DeQuantStub()
#           (dequant2): DeQuantStub()
#           (dequant3): DeQuantStub()
#           (dequant4): DeQuantStub()
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (rms_2): RMSNorm()
#         (mlp): QuantizedMLP(
#           (quant1): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-4.115692615509033, max_val=5.309828281402588)
#           )
#           (quant2): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-8.51618766784668, max_val=10.000864028930664)
#           )
#           (dequant1): DeQuantStub()
#           (dequant2): DeQuantStub()
#           (dequant3): DeQuantStub()
#           (c_fc1): Linear(
#             in_features=144, out_features=512, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-6.610525131225586, max_val=4.835999965667725)
#           )
#           (c_fc2): Linear(
#             in_features=144, out_features=512, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-4.2657341957092285, max_val=3.96667218208313)
#           )
#           (c_proj): Linear(
#             in_features=512, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-5.258166790008545, max_val=5.393286228179932)
#           )
#         )
#       )
#       (7): QuantizedBlock(
#         (rms_1): RMSNorm()
#         (attn): QuantizedCausalSelfAttention(
#           (q_proj): Linear(
#             in_features=144, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-5.9678874015808105, max_val=4.593448638916016)
#           )
#           (kv_proj): Linear(
#             in_features=144, out_features=288, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-4.848456382751465, max_val=4.799729347229004)
#           )
#           (c_proj): Linear(
#             in_features=144, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-2.6240975856781006, max_val=2.9561984539031982)
#           )
#           (quant1): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-4.260607719421387, max_val=5.672367572784424)
#           )
#           (quant2): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-3.132906675338745, max_val=2.9493048191070557)
#           )
#           (dequant1): DeQuantStub()
#           (dequant2): DeQuantStub()
#           (dequant3): DeQuantStub()
#           (dequant4): DeQuantStub()
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (rms_2): RMSNorm()
#         (mlp): QuantizedMLP(
#           (quant1): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-4.286903381347656, max_val=5.784939765930176)
#           )
#           (quant2): QuantStub(
#             (activation_post_process): MinMaxObserver(min_val=-13.804671287536621, max_val=8.731447219848633)
#           )
#           (dequant1): DeQuantStub()
#           (dequant2): DeQuantStub()
#           (dequant3): DeQuantStub()
#           (c_fc1): Linear(
#             in_features=144, out_features=512, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-5.034325122833252, max_val=5.105716705322266)
#           )
#           (c_fc2): Linear(
#             in_features=144, out_features=512, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-4.472843647003174, max_val=5.473108291625977)
#           )
#           (c_proj): Linear(
#             in_features=512, out_features=144, bias=False
#             (activation_post_process): MinMaxObserver(min_val=-8.917675971984863, max_val=8.195135116577148)
#           )
#         )
#       )
#     )
#     (ln_f): RMSNorm()
#   )
# )

# %%
q_lightning_module.model = torch.ao.quantization.convert(q_lightning_module.model)
# Out:
# c:\Python\Lib\site-packages\torch\ao\quantization\utils.py:339: UserWarning: must run observer before calling calculate_qparams. Returning default values.
#   warnings.warn(

# %%
q_lightning_module.model
# Out:
# QuantizedLagLlamaModel(
#   (param_proj): QuantizedPtArgProj(
#     (proj): ModuleList(
#       (0): QuantizedLinear(in_features=144, out_features=1, scale=0.08245067298412323, zero_point=50, qscheme=torch.per_tensor_affine)
#       (1): QuantizedLinear(in_features=144, out_features=1, scale=0.06543944776058197, zero_point=53, qscheme=torch.per_tensor_affine)
#       (2): QuantizedLinear(in_features=144, out_features=1, scale=0.0438690148293972, zero_point=73, qscheme=torch.per_tensor_affine)
#     )
#     (domain_map): LambdaLayer()
#     (quant): Quantize(scale=tensor([0.0855]), zero_point=tensor([52]), dtype=torch.quint8)
#     (dequant): DeQuantize()
#   )
#   (quant1): Quantize(scale=tensor([0.0875]), zero_point=tensor([53]), dtype=torch.quint8)
#   (dequant1): DeQuantize()
#   (quant2): Quantize(scale=tensor([1.]), zero_point=tensor([0]), dtype=torch.quint8)
#   (dequant2): DeQuantize()
#   (transformer): ModuleDict(
#     (wte): QuantizedLinear(in_features=92, out_features=144, scale=0.04919265955686569, zero_point=71, qscheme=torch.per_tensor_affine)
#     (h): ModuleList(
#       (0): QuantizedBlock(
#         (rms_1): RMSNorm()
#         (attn): QuantizedCausalSelfAttention(
#           (q_proj): QuantizedLinear(in_features=144, out_features=144, scale=0.07166502624750137, zero_point=60, qscheme=torch.per_tensor_affine)
#           (kv_proj): QuantizedLinear(in_features=144, out_features=288, scale=0.06662362068891525, zero_point=68, qscheme=torch.per_tensor_affine)
#           (c_proj): QuantizedLinear(in_features=144, out_features=144, scale=0.023034246638417244, zero_point=59, qscheme=torch.per_tensor_affine)
#           (quant1): Quantize(scale=tensor([0.0557]), zero_point=tensor([66]), dtype=torch.quint8)
#           (quant2): Quantize(scale=tensor([0.0350]), zero_point=tensor([56]), dtype=torch.quint8)
#           (dequant1): DeQuantize()
#           (dequant2): DeQuantize()
#           (dequant3): DeQuantize()
#           (dequant4): DeQuantize()
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (rms_2): RMSNorm()
#         (mlp): QuantizedMLP(
#           (quant1): Quantize(scale=tensor([0.0632]), zero_point=tensor([67]), dtype=torch.quint8)
#           (quant2): Quantize(scale=tensor([0.1139]), zero_point=tensor([92]), dtype=torch.quint8)
#           (dequant1): DeQuantize()
#           (dequant2): DeQuantize()
#           (dequant3): DeQuantize()
#           (c_fc1): QuantizedLinear(in_features=144, out_features=512, scale=0.05354461073875427, zero_point=73, qscheme=torch.per_tensor_affine)
#           (c_fc2): QuantizedLinear(in_features=144, out_features=512, scale=0.06683823466300964, zero_point=69, qscheme=torch.per_tensor_affine)
#           (c_proj): QuantizedLinear(in_features=512, out_features=144, scale=0.07678786665201187, zero_point=73, qscheme=torch.per_tensor_affine)
#         )
#       )
#       (1): QuantizedBlock(
#         (rms_1): RMSNorm()
#         (attn): QuantizedCausalSelfAttention(
#           (q_proj): QuantizedLinear(in_features=144, out_features=144, scale=0.07661699503660202, zero_point=64, qscheme=torch.per_tensor_affine)
#           (kv_proj): QuantizedLinear(in_features=144, out_features=288, scale=0.054227061569690704, zero_point=66, qscheme=torch.per_tensor_affine)
#           (c_proj): QuantizedLinear(in_features=144, out_features=144, scale=0.016312940046191216, zero_point=65, qscheme=torch.per_tensor_affine)
#           (quant1): Quantize(scale=tensor([0.0589]), zero_point=tensor([66]), dtype=torch.quint8)
#           (quant2): Quantize(scale=tensor([0.0262]), zero_point=tensor([58]), dtype=torch.quint8)
#           (dequant1): DeQuantize()
#           (dequant2): DeQuantize()
#           (dequant3): DeQuantize()
#           (dequant4): DeQuantize()
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (rms_2): RMSNorm()
#         (mlp): QuantizedMLP(
#           (quant1): Quantize(scale=tensor([0.0619]), zero_point=tensor([65]), dtype=torch.quint8)
#           (quant2): Quantize(scale=tensor([0.0790]), zero_point=tensor([70]), dtype=torch.quint8)
#           (dequant1): DeQuantize()
#           (dequant2): DeQuantize()
#           (dequant3): DeQuantize()
#           (c_fc1): QuantizedLinear(in_features=144, out_features=512, scale=0.05013463646173477, zero_point=67, qscheme=torch.per_tensor_affine)
#           (c_fc2): QuantizedLinear(in_features=144, out_features=512, scale=0.050755929201841354, zero_point=66, qscheme=torch.per_tensor_affine)
#           (c_proj): QuantizedLinear(in_features=512, out_features=144, scale=0.04720696061849594, zero_point=48, qscheme=torch.per_tensor_affine)
#         )
#       )
#       (2): QuantizedBlock(
#         (rms_1): RMSNorm()
#         (attn): QuantizedCausalSelfAttention(
#           (q_proj): QuantizedLinear(in_features=144, out_features=144, scale=0.07254265248775482, zero_point=64, qscheme=torch.per_tensor_affine)
#           (kv_proj): QuantizedLinear(in_features=144, out_features=288, scale=0.07974875718355179, zero_point=59, qscheme=torch.per_tensor_affine)
#           (c_proj): QuantizedLinear(in_features=144, out_features=144, scale=0.021220995113253593, zero_point=67, qscheme=torch.per_tensor_affine)
#           (quant1): Quantize(scale=tensor([0.0618]), zero_point=tensor([62]), dtype=torch.quint8)
#           (quant2): Quantize(scale=tensor([0.0353]), zero_point=tensor([60]), dtype=torch.quint8)
#           (dequant1): DeQuantize()
#           (dequant2): DeQuantize()
#           (dequant3): DeQuantize()
#           (dequant4): DeQuantize()
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (rms_2): RMSNorm()
#         (mlp): QuantizedMLP(
#           (quant1): Quantize(scale=tensor([0.0634]), zero_point=tensor([61]), dtype=torch.quint8)
#           (quant2): Quantize(scale=tensor([0.0955]), zero_point=tensor([72]), dtype=torch.quint8)
#           (dequant1): DeQuantize()
#           (dequant2): DeQuantize()
#           (dequant3): DeQuantize()
#           (c_fc1): QuantizedLinear(in_features=144, out_features=512, scale=0.05456000939011574, zero_point=61, qscheme=torch.per_tensor_affine)
#           (c_fc2): QuantizedLinear(in_features=144, out_features=512, scale=0.04958008602261543, zero_point=68, qscheme=torch.per_tensor_affine)
#           (c_proj): QuantizedLinear(in_features=512, out_features=144, scale=0.0592481791973114, zero_point=51, qscheme=torch.per_tensor_affine)
#         )
#       )
#       (3): QuantizedBlock(
#         (rms_1): RMSNorm()
#         (attn): QuantizedCausalSelfAttention(
#           (q_proj): QuantizedLinear(in_features=144, out_features=144, scale=0.08255574107170105, zero_point=57, qscheme=torch.per_tensor_affine)
#           (kv_proj): QuantizedLinear(in_features=144, out_features=288, scale=0.06852229684591293, zero_point=54, qscheme=torch.per_tensor_affine)
#           (c_proj): QuantizedLinear(in_features=144, out_features=144, scale=0.028202585875988007, zero_point=69, qscheme=torch.per_tensor_affine)
#           (quant1): Quantize(scale=tensor([0.0664]), zero_point=tensor([61]), dtype=torch.quint8)
#           (quant2): Quantize(scale=tensor([0.0519]), zero_point=tensor([61]), dtype=torch.quint8)
#           (dequant1): DeQuantize()
#           (dequant2): DeQuantize()
#           (dequant3): DeQuantize()
#           (dequant4): DeQuantize()
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (rms_2): RMSNorm()
#         (mlp): QuantizedMLP(
#           (quant1): Quantize(scale=tensor([0.0669]), zero_point=tensor([61]), dtype=torch.quint8)
#           (quant2): Quantize(scale=tensor([0.1176]), zero_point=tensor([55]), dtype=torch.quint8)
#           (dequant1): DeQuantize()
#           (dequant2): DeQuantize()
#           (dequant3): DeQuantize()
#           (c_fc1): QuantizedLinear(in_features=144, out_features=512, scale=0.07039584964513779, zero_point=66, qscheme=torch.per_tensor_affine)
#           (c_fc2): QuantizedLinear(in_features=144, out_features=512, scale=0.06244385242462158, zero_point=55, qscheme=torch.per_tensor_affine)
#           (c_proj): QuantizedLinear(in_features=512, out_features=144, scale=0.07374256104230881, zero_point=60, qscheme=torch.per_tensor_affine)
#         )
#       )
#       (4): QuantizedBlock(
#         (rms_1): RMSNorm()
#         (attn): QuantizedCausalSelfAttention(
#           (q_proj): QuantizedLinear(in_features=144, out_features=144, scale=0.11701638251543045, zero_point=79, qscheme=torch.per_tensor_affine)
#           (kv_proj): QuantizedLinear(in_features=144, out_features=288, scale=0.1014697477221489, zero_point=56, qscheme=torch.per_tensor_affine)
#           (c_proj): QuantizedLinear(in_features=144, out_features=144, scale=0.05559777095913887, zero_point=64, qscheme=torch.per_tensor_affine)
#           (quant1): Quantize(scale=tensor([0.0665]), zero_point=tensor([64]), dtype=torch.quint8)
#           (quant2): Quantize(scale=tensor([0.0742]), zero_point=tensor([71]), dtype=torch.quint8)
#           (dequant1): DeQuantize()
#           (dequant2): DeQuantize()
#           (dequant3): DeQuantize()
#           (dequant4): DeQuantize()
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (rms_2): RMSNorm()
#         (mlp): QuantizedMLP(
#           (quant1): Quantize(scale=tensor([0.0714]), zero_point=tensor([64]), dtype=torch.quint8)
#           (quant2): Quantize(scale=tensor([0.1528]), zero_point=tensor([69]), dtype=torch.quint8)
#           (dequant1): DeQuantize()
#           (dequant2): DeQuantize()
#           (dequant3): DeQuantize()
#           (c_fc1): QuantizedLinear(in_features=144, out_features=512, scale=0.07343271374702454, zero_point=58, qscheme=torch.per_tensor_affine)
#           (c_fc2): QuantizedLinear(in_features=144, out_features=512, scale=0.05633605271577835, zero_point=57, qscheme=torch.per_tensor_affine)
#           (c_proj): QuantizedLinear(in_features=512, out_features=144, scale=0.06360414624214172, zero_point=63, qscheme=torch.per_tensor_affine)
#         )
#       )
#       (5): QuantizedBlock(
#         (rms_1): RMSNorm()
#         (attn): QuantizedCausalSelfAttention(
#           (q_proj): QuantizedLinear(in_features=144, out_features=144, scale=0.0771619975566864, zero_point=67, qscheme=torch.per_tensor_affine)
#           (kv_proj): QuantizedLinear(in_features=144, out_features=288, scale=0.09186648577451706, zero_point=52, qscheme=torch.per_tensor_affine)
#           (c_proj): QuantizedLinear(in_features=144, out_features=144, scale=0.05120273306965828, zero_point=61, qscheme=torch.per_tensor_affine)
#           (quant1): Quantize(scale=tensor([0.0742]), zero_point=tensor([67]), dtype=torch.quint8)
#           (quant2): Quantize(scale=tensor([0.0670]), zero_point=tensor([61]), dtype=torch.quint8)
#           (dequant1): DeQuantize()
#           (dequant2): DeQuantize()
#           (dequant3): DeQuantize()
#           (dequant4): DeQuantize()
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (rms_2): RMSNorm()
#         (mlp): QuantizedMLP(
#           (quant1): Quantize(scale=tensor([0.0697]), zero_point=tensor([63]), dtype=torch.quint8)
#           (quant2): Quantize(scale=tensor([0.1312]), zero_point=tensor([62]), dtype=torch.quint8)
#           (dequant1): DeQuantize()
#           (dequant2): DeQuantize()
#           (dequant3): DeQuantize()
#           (c_fc1): QuantizedLinear(in_features=144, out_features=512, scale=0.08576300740242004, zero_point=71, qscheme=torch.per_tensor_affine)
#           (c_fc2): QuantizedLinear(in_features=144, out_features=512, scale=0.05295133963227272, zero_point=64, qscheme=torch.per_tensor_affine)
#           (c_proj): QuantizedLinear(in_features=512, out_features=144, scale=0.07926809042692184, zero_point=55, qscheme=torch.per_tensor_affine)
#         )
#       )
#       (6): QuantizedBlock(
#         (rms_1): RMSNorm()
#         (attn): QuantizedCausalSelfAttention(
#           (q_proj): QuantizedLinear(in_features=144, out_features=144, scale=0.1082499772310257, zero_point=71, qscheme=torch.per_tensor_affine)
#           (kv_proj): QuantizedLinear(in_features=144, out_features=288, scale=0.08869668841362, zero_point=67, qscheme=torch.per_tensor_affine)
#           (c_proj): QuantizedLinear(in_features=144, out_features=144, scale=0.046572715044021606, zero_point=55, qscheme=torch.per_tensor_affine)
#           (quant1): Quantize(scale=tensor([0.0725]), zero_point=tensor([58]), dtype=torch.quint8)
#           (quant2): Quantize(scale=tensor([0.0496]), zero_point=tensor([65]), dtype=torch.quint8)
#           (dequant1): DeQuantize()
#           (dequant2): DeQuantize()
#           (dequant3): DeQuantize()
#           (dequant4): DeQuantize()
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (rms_2): RMSNorm()
#         (mlp): QuantizedMLP(
#           (quant1): Quantize(scale=tensor([0.0742]), zero_point=tensor([55]), dtype=torch.quint8)
#           (quant2): Quantize(scale=tensor([0.1458]), zero_point=tensor([58]), dtype=torch.quint8)
#           (dequant1): DeQuantize()
#           (dequant2): DeQuantize()
#           (dequant3): DeQuantize()
#           (c_fc1): QuantizedLinear(in_features=144, out_features=512, scale=0.09013012051582336, zero_point=73, qscheme=torch.per_tensor_affine)
#           (c_fc2): QuantizedLinear(in_features=144, out_features=512, scale=0.06482210010290146, zero_point=66, qscheme=torch.per_tensor_affine)
#           (c_proj): QuantizedLinear(in_features=512, out_features=144, scale=0.08386971056461334, zero_point=63, qscheme=torch.per_tensor_affine)
#         )
#       )
#       (7): QuantizedBlock(
#         (rms_1): RMSNorm()
#         (attn): QuantizedCausalSelfAttention(
#           (q_proj): QuantizedLinear(in_features=144, out_features=144, scale=0.08316013216972351, zero_point=72, qscheme=torch.per_tensor_affine)
#           (kv_proj): QuantizedLinear(in_features=144, out_features=288, scale=0.07596996426582336, zero_point=64, qscheme=torch.per_tensor_affine)
#           (c_proj): QuantizedLinear(in_features=144, out_features=144, scale=0.04393933713436127, zero_point=60, qscheme=torch.per_tensor_affine)
#           (quant1): Quantize(scale=tensor([0.0782]), zero_point=tensor([54]), dtype=torch.quint8)
#           (quant2): Quantize(scale=tensor([0.0479]), zero_point=tensor([65]), dtype=torch.quint8)
#           (dequant1): DeQuantize()
#           (dequant2): DeQuantize()
#           (dequant3): DeQuantize()
#           (dequant4): DeQuantize()
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (rms_2): RMSNorm()
#         (mlp): QuantizedMLP(
#           (quant1): Quantize(scale=tensor([0.0793]), zero_point=tensor([54]), dtype=torch.quint8)
#           (quant2): Quantize(scale=tensor([0.1774]), zero_point=tensor([78]), dtype=torch.quint8)
#           (dequant1): DeQuantize()
#           (dequant2): DeQuantize()
#           (dequant3): DeQuantize()
#           (c_fc1): QuantizedLinear(in_features=144, out_features=512, scale=0.07984284311532974, zero_point=63, qscheme=torch.per_tensor_affine)
#           (c_fc2): QuantizedLinear(in_features=144, out_features=512, scale=0.07831458002328873, zero_point=57, qscheme=torch.per_tensor_affine)
#           (c_proj): QuantizedLinear(in_features=512, out_features=144, scale=0.13474655151367188, zero_point=66, qscheme=torch.per_tensor_affine)
#         )
#       )
#     )
#     (ln_f): RMSNorm()
#   )
# )

# %%
q_forecasts, q_tss, q_lightning_module, q_estimator = observe_value_ranges(q_estimator, q_lightning_module, backtest_dataset, num_samples)

# %%
plt.figure(figsize=(20, 15))
date_formater = mdates.DateFormatter('%b, %d')
plt.rcParams.update({'font.size': 15})

# Iterate through the first 9 series, and plot the predicted samples
for idx, (forecast, ts) in islice(enumerate(zip(q_forecasts, q_tss)), 9):
    ax = plt.subplot(3, 3, idx+1)

    plt.plot(ts[-4 * prediction_length:].to_timestamp(), label="target", )
    forecast.plot( color='r')
    plt.xticks(rotation=60)
    ax.xaxis.set_major_formatter(date_formater)
    ax.set_title(forecast.item_id)

plt.gcf().tight_layout()
plt.legend()
plt.show()

# %%
prediction_length
# Out:
# 24

# %%
from gluonts.evaluation.metrics import mse, abs_error
import numpy as np

# %%
print("MSE:",mse(q_tss[0].values.reshape(-1)[-prediction_length:], np.median(q_forecasts[0].samples, axis=0)))
# Out:
# MSE: 5369.97

# %%
print("Mean Absolute Error:",abs_error(q_tss[0].values.reshape(-1)[-prediction_length:], np.median(q_forecasts[0].samples, axis=0))/ prediction_length)
# Out:
# Mean Absolute Error: 62.35084025065104
